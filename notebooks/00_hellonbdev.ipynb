# %%
# default_exp hellonbdev

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello('xinhao')
# Out:
# 'Hello xinhao!'

# %%
from fastcore.test import *
test_eq(say_hello("Jeremy"), "Hello Jeremy!")

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
# Out:
# RDKit WARNING: [16:43:57] Enabling RDKit 2019.09.3 jupyter extensions

# %%
m = Chem.MolFromSmiles('O=S1(=O)c2ccccc2-c2ccccc21')
m
